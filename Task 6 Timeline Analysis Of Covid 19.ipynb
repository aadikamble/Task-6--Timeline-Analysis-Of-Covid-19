# %% [raw]
# AADITYA KAMBLE

# %% [markdown]
# # Task 6:-Timeline Analysis Of Covid 19

# %% [markdown]
# # Technical Stack : Sikit Learn, Numpy Array, Pandas, Matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# # Step 1 - Reading the data from source

# %%
df=pd.read_csv("C:/Users/abc/Desktop/xyz/full_data.csv")
df
# Out:
#              date     location  new_cases  new_deaths  total_cases  \
# 0      12/31/2019  Afghanistan        0.0         0.0          NaN
# 1        1/1/2020  Afghanistan        0.0         0.0          NaN
# 2        1/2/2020  Afghanistan        0.0         0.0          NaN
# 3        1/3/2020  Afghanistan        0.0         0.0          NaN
# 4        1/4/2020  Afghanistan        0.0         0.0          NaN
# ...           ...          ...        ...         ...          ...
# 50811  10/16/2020     Zimbabwe       20.0         0.0       8075.0
# 50812  10/17/2020     Zimbabwe       24.0         0.0       8099.0
# 50813  10/18/2020     Zimbabwe       11.0         0.0       8110.0
# 50814  10/19/2020     Zimbabwe       37.0         0.0       8147.0
# 50815  10/20/2020     Zimbabwe       12.0         1.0       8159.0
#
#        total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0               NaN           NaN            NaN             NaN
# ...

# %%
df.head()
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths  \
# 0  12/31/2019  Afghanistan        0.0         0.0          NaN           NaN
# 1    1/1/2020  Afghanistan        0.0         0.0          NaN           NaN
# 2    1/2/2020  Afghanistan        0.0         0.0          NaN           NaN
# 3    1/3/2020  Afghanistan        0.0         0.0          NaN           NaN
# 4    1/4/2020  Afghanistan        0.0         0.0          NaN           NaN
#
#    weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# 0           NaN            NaN             NaN              NaN
# 1           NaN            NaN             NaN              NaN
# 2           NaN            NaN             NaN              NaN
# 3           NaN            NaN             NaN              NaN
# 4           NaN            NaN             NaN              NaN

# %%
df.tail()
# Out:
#              date  location  new_cases  new_deaths  total_cases  total_deaths  \
# 50811  10/16/2020  Zimbabwe       20.0         0.0       8075.0         231.0
# 50812  10/17/2020  Zimbabwe       24.0         0.0       8099.0         231.0
# 50813  10/18/2020  Zimbabwe       11.0         0.0       8110.0         231.0
# 50814  10/19/2020  Zimbabwe       37.0         0.0       8147.0         231.0
# 50815  10/20/2020  Zimbabwe       12.0         1.0       8159.0         232.0
#
#        weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# 50811         124.0            2.0           225.0              3.0
# 50812         105.0            2.0           241.0              3.0
# 50813         100.0            1.0           225.0              3.0
# 50814         136.0            1.0           262.0              3.0
# 50815         138.0            2.0           261.0              4.0

# %% [markdown]
# # Step 2 - Data Exploration

# %%
df.describe()
# Out:
#            new_cases    new_deaths   total_cases  total_deaths  weekly_cases  \
# count   50491.000000  50491.000000  4.753300e+04  3.874900e+04  4.970400e+04
# mean     1603.144323     44.335347  1.335921e+05  6.090187e+03  1.109267e+04
# std     14439.062869    370.496009  1.334720e+06  4.914814e+04  9.925976e+04
# min     -8261.000000  -1918.000000  1.000000e+00  1.000000e+00 -3.864000e+03
# 25%         0.000000      0.000000  1.410000e+02  1.100000e+01  5.000000e+00
# 50%        12.000000      0.000000  1.708000e+03  7.200000e+01  1.190000e+02
# 75%       190.000000      3.000000  1.680000e+04  6.110000e+02  1.385250e+03
# max    400350.000000  10468.000000  4.047250e+07  1.119283e+06  2.552614e+06
#
#        weekly_deaths  biweekly_cases  biweekly_deaths
# count   49704.000000    4.822700e+04     48227.000000
# mean      311.036516    2.215560e+04       630.230638
# std      2523.569556    1.967114e+05      5062.950505
# min     -1625.000000   -9.050000e+02     -1616.000000
# ...

# %%
df.describe()
# Out:
#            new_cases    new_deaths   total_cases  total_deaths  weekly_cases  \
# count   50491.000000  50491.000000  4.753300e+04  3.874900e+04  4.970400e+04
# mean     1603.144323     44.335347  1.335921e+05  6.090187e+03  1.109267e+04
# std     14439.062869    370.496009  1.334720e+06  4.914814e+04  9.925976e+04
# min     -8261.000000  -1918.000000  1.000000e+00  1.000000e+00 -3.864000e+03
# 25%         0.000000      0.000000  1.410000e+02  1.100000e+01  5.000000e+00
# 50%        12.000000      0.000000  1.708000e+03  7.200000e+01  1.190000e+02
# 75%       190.000000      3.000000  1.680000e+04  6.110000e+02  1.385250e+03
# max    400350.000000  10468.000000  4.047250e+07  1.119283e+06  2.552614e+06
#
#        weekly_deaths  biweekly_cases  biweekly_deaths
# count   49704.000000    4.822700e+04     48227.000000
# mean      311.036516    2.215560e+04       630.230638
# std      2523.569556    1.967114e+05      5062.950505
# min     -1625.000000   -9.050000e+02     -1616.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50816 entries, 0 to 50815
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             50816 non-null  object
#  1   location         50816 non-null  object
#  2   new_cases        50491 non-null  float64
#  3   new_deaths       50491 non-null  float64
#  4   total_cases      47533 non-null  float64
#  5   total_deaths     38749 non-null  float64
#  6   weekly_cases     49704 non-null  float64
#  7   weekly_deaths    49704 non-null  float64
#  8   biweekly_cases   48227 non-null  float64
#  9   biweekly_deaths  48227 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 3.5+ MB

# %%
df.columns
# Out:
# Index(['date', 'location', 'new_cases', 'new_deaths', 'total_cases',
#        'total_deaths', 'weekly_cases', 'weekly_deaths', 'biweekly_cases',
#        'biweekly_deaths'],
#       dtype='object')

# %%
df.head()
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths  \
# 0  12/31/2019  Afghanistan        0.0         0.0          NaN           NaN
# 1    1/1/2020  Afghanistan        0.0         0.0          NaN           NaN
# 2    1/2/2020  Afghanistan        0.0         0.0          NaN           NaN
# 3    1/3/2020  Afghanistan        0.0         0.0          NaN           NaN
# 4    1/4/2020  Afghanistan        0.0         0.0          NaN           NaN
#
#    weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# 0           NaN            NaN             NaN              NaN
# 1           NaN            NaN             NaN              NaN
# 2           NaN            NaN             NaN              NaN
# 3           NaN            NaN             NaN              NaN
# 4           NaN            NaN             NaN              NaN

# %%
df.shape
# Out:
# (50816, 10)

# %%
duplicate_rows_df=df[df.duplicated()]
print("no of duplicate raws=",duplicate_rows_df.shape)
# Out:
# no of duplicate raws= (0, 10)

# %%
df.count()
# Out:
# date               50816
# location           50816
# new_cases          50491
# new_deaths         50491
# total_cases        47533
# total_deaths       38749
# weekly_cases       49704
# weekly_deaths      49704
# biweekly_cases     48227
# biweekly_deaths    48227
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date                   0
# location               0
# new_cases            325
# new_deaths           325
# total_cases         3283
# total_deaths       12067
# weekly_cases        1112
# weekly_deaths       1112
# biweekly_cases      2589
# biweekly_deaths     2589
# dtype: int64

# %% [markdown]
# # Step 3 - Data Visualization

# %%
sns.distplot(df['total_cases'])
sns.distplot(df['new_cases']);

# %%
sns.distplot(df['total_cases'])
sns.distplot(df['new_cases']);

# %%
sns.pairplot(df, size=2.5);
# Out:
# C:\Users\abc\anaconda 3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df, kind='reg')

# %%
sns.distplot(df['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %% [markdown]
# # Step 4 - Timeseries Analysis Of Covid 19

# %%
df.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df.new_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_deaths=df[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# # Thank You
